# %% [markdown]
# # Aula 04: Algoritmos Evolutivos Multiobjetivo: Teoria e Aplicações
#
# **Professor** PhD Jackson Antonio do Prado Lima
#
# **Contato:** `[jacksonpradolima at @gmail.com]` - Por favor, use o prefixo `[SBSE-CursoBR]` no assunto
#
# ---
#
# **Agenda:**
# - Motivação
# - Conceitos Básicos
# - Otimização  Multiobjetivos
# - Algoritmos Evolutivos Multiobjetivos
# - Aplicação
# - Conclusões
# - Comunidade EMO
# - Livros
#
# ---

# %% [markdown]
# ## Introdução
#
# ### Motivação
#
# - Porque Otimização Multiobjetivo ?
# - A maior parte dos problemas possuem vários objetivos, normalmente conflitantes.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Diferenças Mono x Multi-Objetivo
#
# ![image.png](attachment:image.png)
#
# - Mono: soluções X no espaço de decisão factível traduzidos em espaço de objetivos f(x)
# - Multi: multiplas soluções em vários vetores de objetivos
#
# ### Multi-Objetivos
#
# Problemas com múltiplos objetivos (Multi-Objetive Problem, MOP) tipicamente colocarão para o projetista um problema de tomada de decisão que envolve a analise das trocas (ou trade-offs) entre objetivos.

# %% [markdown]
# ## Conceitos
#
# ### Problema e Soluções
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Classificação das Soluções
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Fronteira de Pareto - Ótima
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Conceitos Básicos
#
# Problema de Otimização Multiobjetivo:
#
# Encontrar o vetor:
#
# ![image.png](attachment:image.png)
#
# sujeito:
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# que otimize:
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# #### Dominância
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Solução Eficiente
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Fronteira
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Otimização Multiobjetivos
#
# - Há dois ou mais objetivos na busca;
# - Busca-se encontrar soluções que possibilitem bons _trade-offs_ entre os objetivos;
# - Existem diversas formas de tratar um problema multiobjetivo.

# %% [markdown]
# ### Estabelecer Prioridades
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Quando Decidir
# - Antes de otimizar
#   - Ranquear objetivos
#   - Definir restrições
#   - Buscar uma solução
#
# - Depois de otimizar
#   - Buscar por um conjunto de soluções
#   - Selecionar uma solução considerando restrições

# %% [markdown]
# ### 2 Objetivos em Multiobjetivos
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Porque Algoritmos Evolutivos
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Classificação Algoritmos
#
# - **Não Pareto**: não produzem certas porções da Fronteira, são eficientes e fáceis de implementar:
#   - Agregação de funções
#   - VEGA
# - **Pareto**: Usam um ranking baseado em dominância e técnicas para manter a diversidade

# %% [markdown]
# ## Algoritmos Evolutivos
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Algoritmos genéticos mono-objetivo
#
# - Os operadores genéticos de mutação e de cruzamento exercem a função de mecanismos de variação.
# - Dependendo do mecanismo de seleção empregado, a atribuição de aptidão pode ser feita com a atribuição do próprio valor da função-objetivo
# - Seleção
# - Solução melhor individuo (arq. Implicito)

# %% [markdown]
# ### Agregação de Funções
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Aptidão em AE's Multiobjetivo
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Rankings
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Atribuição de Aptidão
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### NSGA-II
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### SPEA2
#
# - O SPEA2 (_Strength Pareto Evolutionary Algorithm_), alem de ter sua população regular, mantém um arquivo externo que armazena soluções não-dominadas;
# - Para cada solução que esta no arquivo e na população e calculado um valor de _strength_, que e usado no cálculo do _fitness_ do indivíduo;
# - O valor de _strength_ de uma solução i corresponde a quantidade de indivíduos j, pertencentes ao arquivo e a população, dominados por i;
# - R = ∑ Strength dos dominadores.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### SPEA2 - Diversidade
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### NSGA-II e SPEA2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Como Avaliar?
#
# - Avaliações  Baseadas em Indicadores
#   - Hypervolume
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Por onde começar?
#
# - JMetal
#   - http://jmetal.sourceforge.net/
#   - NSGA-II, SPEA2, PAES, PESA-II, OMOPSO, MOCell, AbYSS, MOEA/D, Densea, CellDE, GDE3, FastPGA, IBEA, SMPSO, SMS-EMOA, dMOPSO, SMPSOhv
#   - Quality indicators: hypervolume, spread, generational distance, inverted generational distance, additive epsilon.
#   - Variable representations: binary, real, binary-coded real, integer, permutation.

# %% [markdown]
# ## Comunidade EMO
#
# - Links:
#   - EMO mailing list:
#   - http://w3.ualg.pt/lists/emo-list/
#
# - EMO bibliografia: http://www.lania.mx/~ccoello/EMOO/
# - EMO conferencias: http://www.mat.ufmg.br/emo2011/

# %% [markdown]
# ## Livros
#
# - Multi-Objective Optimization using Evolutionary Algorithms. Kalyanmoy Deb, Wiley, 2001
# - Evolutionary Algorithms for Solving Multi -Objective Problems, Carlos A. Coello Coello, David A. Van Veldhuizen & Gary B. Lamont, Kluwer, 2nd Ed. 2007
# - Multiobjective Optimization—Interactive and Evolutionary Approaches, J. Branke, K. Deb, K. Miettinen, and R. Slowinski, editors, volume 5252 of LNCS. Springer, 2008
